# %%
import pandas as pd
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.metrics import silhouette_score

# %%
# Import necessary libraries
import pandas as pd

# Specify the path to the BindingDB dataset file
file_path = 'BindingDB_All.tsv'

# Step 1: Selective loading of columns to reduce memory usage
# Specify the columns to load
list_columns_kept = ['Ligand SMILES', 'Target Name', 'Target Source Organism According to Curator or DataSource', 'Target Name', 'Ki (nM)', 'IC50 (nM)', 'Kd (nM)', 'EC50 (nM)', 'kon (M-1-s-1)', 'koff (s-1)', 'pH', 'Temp (C)', 
                'Number of Protein Chains in Target (>1 implies a multichain complex)', 'BindingDB Target Chain Sequence', 'BindingDB Target Chain Sequence.1',
                'BindingDB Target Chain Sequence.2', 'BindingDB Target Chain Sequence.3', 'BindingDB Target Chain Sequence.4', 'BindingDB Target Chain Sequence.5',
                'BindingDB Target Chain Sequence.6', 'BindingDB Target Chain Sequence.7', 'BindingDB Target Chain Sequence.8', 'BindingDB Target Chain Sequence.9', 
                'BindingDB Target Chain Sequence.10', 'BindingDB Target Chain Sequence.11', 'BindingDB Target Chain Sequence.12']
data = pd.read_csv(file_path, sep='\t', usecols=list_columns_kept, na_values=['', 'NULL'])
df = pd.DataFrame(data)
df.head()
# Out:
# /var/folders/7z/y2p4cj3n02g7g064sxpd55380000gn/T/ipykernel_15690/3501067610.py:14: DtypeWarning:
#
# Columns (8,9,10,11,12,13,15,50,62,74,86,98,110,122,134,146,158,170,182) have mixed types. Specify dtype option on import or set low_memory=False.
#                                        Ligand SMILES  \
# 0  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=...
# 1  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(C\C=C\c2cn...
# 2  O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC2CC2)C(=...
# 3  OCCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@...
# 4  OCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H...
#
#                               Target Name  \
# 0  Dimer of Gag-Pol polyprotein [501-599]
# 1  Dimer of Gag-Pol polyprotein [501-599]
# 2  Dimer of Gag-Pol polyprotein [501-599]
# 3  Dimer of Gag-Pol polyprotein [501-599]
# 4  Dimer of Gag-Pol polyprotein [501-599]
#
#   Target Source Organism According to Curator or DataSource Ki (nM) IC50 (nM)  \
# 0                     Human immunodeficiency virus 1           0.24       NaN
# 1                     Human immunodeficiency virus 1           0.25       NaN
# 2                     Human immunodeficiency virus 1           0.41       NaN
# 3                     Human immunodeficiency virus 1            0.8       NaN
# 4                     Human immunodeficiency virus 1           0.99       NaN
#
#   Kd (nM) EC50 (nM) kon (M-1-s-1) koff (s-1)   pH  ...  \
# 0     NaN       NaN           NaN        NaN  5.5  ...
# 1     NaN       NaN           NaN        NaN  5.5  ...
# 2     NaN       NaN           NaN        NaN  5.5  ...
# 3     NaN       NaN           NaN        NaN  5.5  ...
# 4     NaN       NaN           NaN        NaN  5.5  ...
#
#   BindingDB Target Chain Sequence.3  BindingDB Target Chain Sequence.4  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   BindingDB Target Chain Sequence.5 BindingDB Target Chain Sequence.6  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   BindingDB Target Chain Sequence.7 BindingDB Target Chain Sequence.8  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   BindingDB Target Chain Sequence.9 BindingDB Target Chain Sequence.10  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#   BindingDB Target Chain Sequence.11 BindingDB Target Chain Sequence.12
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
# [5 rows x 25 columns]

# %%
#metric analysis to find which one between Ki and Kd are mostly present values in the dataset
non_nan_ki = data['Ki (nM)'].count()
print('Numbers of data containing Ki information: ', non_nan_ki)

non_nan_kd = data['Kd (nM)'].count()
print('Numbers of data containing Kd information: ', non_nan_kd)
# Out:
# Numbers of data containing Ki information:  591908
# Numbers of data containing Kd information:  110827

# %% [markdown]
# We have information about Ki more than Kd in the dataset.

# %%
# Drop rows that contain any NaN value
df_cleaned = data.dropna(subset= ['Ligand SMILES', 'Target Name', 'Target Source Organism According to Curator or DataSource', 'Ki (nM)'], how = 'any')
df_cleaned.reset_index
#df_cleaned.head()
# Out:
# <bound method DataFrame.reset_index of                                              Ligand SMILES  \
# 0        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=...
# 1        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(C\C=C\c2cn...
# 2        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC2CC2)C(=...
# 3        OCCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@...
# 4        OCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H...
# ...                                                    ...
# 2913146                            NOCc1ccc(cc1)S(N)(=O)=O
# 2913147                         CC(=O)Nc1nnc(s1)S(N)(=O)=O
# 2913148  CC(C)C[C@H](NC(=O)[C@H](CO)NC(=O)\C=N\OCc1ccc(...
# 2913149  CC(C)C[C@H](NC(=O)[C@H](CO)NC(=O)\C=N\OCc1ccc(...
# 2913150   NC(=O)[C@H](CO)NC(=O)\C=N\OCc1ccc(cc1)S(N)(=O)=O
#
#                                     Target Name  \
# 0        Dimer of Gag-Pol polyprotein [501-599]
# 1        Dimer of Gag-Pol polyprotein [501-599]
# 2        Dimer of Gag-Pol polyprotein [501-599]
# 3        Dimer of Gag-Pol polyprotein [501-599]
# 4        Dimer of Gag-Pol polyprotein [501-599]
# ...                                         ...
# 2913146                   Carbonic anhydrase 12
# 2913147                   Carbonic anhydrase 12
# 2913148                   Carbonic anhydrase 12
# 2913149                   Carbonic anhydrase 12
# 2913150                   Carbonic anhydrase 12
#
#         Target Source Organism According to Curator or DataSource Ki (nM)  \
# 0                           Human immunodeficiency virus 1           0.24
# 1                           Human immunodeficiency virus 1           0.25
# 2                           Human immunodeficiency virus 1           0.41
# 3                           Human immunodeficiency virus 1            0.8
# 4                           Human immunodeficiency virus 1           0.99
# ...                                                    ...            ...
# 2913146                                       Homo sapiens           5400
# 2913147                                       Homo sapiens            5.7
# 2913148                                       Homo sapiens           9600
# 2913149                                       Homo sapiens          14000
# 2913150                                       Homo sapiens           5100
#
#         IC50 (nM) Kd (nM) EC50 (nM) kon (M-1-s-1) koff (s-1)   pH  ...  \
# 0             NaN     NaN       NaN           NaN        NaN  5.5  ...
# 1             NaN     NaN       NaN           NaN        NaN  5.5  ...
# 2             NaN     NaN       NaN           NaN        NaN  5.5  ...
# 3             NaN     NaN       NaN           NaN        NaN  5.5  ...
# 4             NaN     NaN       NaN           NaN        NaN  5.5  ...
# ...           ...     ...       ...           ...        ...  ...  ...
# 2913146       NaN     NaN       NaN           NaN        NaN  NaN  ...
# 2913147       NaN     NaN       NaN           NaN        NaN  NaN  ...
# 2913148       NaN     NaN       NaN           NaN        NaN  NaN  ...
# 2913149       NaN     NaN       NaN           NaN        NaN  NaN  ...
# 2913150       NaN     NaN       NaN           NaN        NaN  NaN  ...
#
#         BindingDB Target Chain Sequence.3  BindingDB Target Chain Sequence.4  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 2913146                               NaN                                NaN
# 2913147                               NaN                                NaN
# 2913148                               NaN                                NaN
# 2913149                               NaN                                NaN
# 2913150                               NaN                                NaN
#
#         BindingDB Target Chain Sequence.5 BindingDB Target Chain Sequence.6  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 2913146                               NaN                               NaN
# 2913147                               NaN                               NaN
# 2913148                               NaN                               NaN
# 2913149                               NaN                               NaN
# 2913150                               NaN                               NaN
#
#         BindingDB Target Chain Sequence.7 BindingDB Target Chain Sequence.8  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 2913146                               NaN                               NaN
# 2913147                               NaN                               NaN
# 2913148                               NaN                               NaN
# 2913149                               NaN                               NaN
# 2913150                               NaN                               NaN
#
#         BindingDB Target Chain Sequence.9 BindingDB Target Chain Sequence.10  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 2913146                               NaN                                NaN
# 2913147                               NaN                                NaN
# 2913148                               NaN                                NaN
# 2913149                               NaN                                NaN
# 2913150                               NaN                                NaN
#
#         BindingDB Target Chain Sequence.11 BindingDB Target Chain Sequence.12
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# ...                                    ...                                ...
# 2913146                                NaN                                NaN
# 2913147                                NaN                                NaN
# 2913148                                NaN                                NaN
# 2913149                                NaN                                NaN
# 2913150                                NaN                                NaN
#
# [444353 rows x 25 columns]>

# %%
#HIV1 targeting coumpunds
hiv_data = df_cleaned[df_cleaned['Target Source Organism According to Curator or DataSource'].str.contains("Human immunodeficiency virus 1", case=False, na=False)].copy()
print(hiv_data.size)
# Out:
# 108750

# %%
hiv_data
# Out:
#                                              Ligand SMILES  \
# 0        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CCCCCC(O)=...
# 1        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(C\C=C\c2cn...
# 2        O[C@@H]1[C@@H](O)[C@@H](Cc2ccccc2)N(CC2CC2)C(=...
# 3        OCCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@...
# 4        OCCCCCN1[C@H](Cc2ccccc2)[C@H](O)[C@@H](O)[C@@H...
# ...                                                    ...
# 2909379          COc1ccc2c(O)c(C(C3CC3)c3ccccc3)c(=O)oc2c1
# 2909380       CCC(Cc1ccccc1)c1cc(O)c(C(CC)c2ccccc2)c(=O)o1
# 2909381  CCC(Cc1ccccc1)c1cc(O)c(C(C2CC2)c2cccc(NC(=O)[C...
# 2909382  CCC[C@@]1(CCc2ccccc2)CC(O)=C([C@H](CC)c2cccc(N...
# 2909383  CCC(c1cccc(NS(=O)(=O)c2ccc(cn2)C#N)c1)c1c(O)c2...
#
#                                     Target Name  \
# 0        Dimer of Gag-Pol polyprotein [501-599]
# 1        Dimer of Gag-Pol polyprotein [501-599]
# 2        Dimer of Gag-Pol polyprotein [501-599]
# 3        Dimer of Gag-Pol polyprotein [501-599]
# 4        Dimer of Gag-Pol polyprotein [501-599]
# ...                                         ...
# 2909379           Gag-Pol polyprotein [489-587]
# 2909380           Gag-Pol polyprotein [489-587]
# 2909381           Gag-Pol polyprotein [489-587]
# 2909382           Gag-Pol polyprotein [489-587]
# 2909383           Gag-Pol polyprotein [489-587]
#
#         Target Source Organism According to Curator or DataSource    Ki (nM)  \
# 0                           Human immunodeficiency virus 1              0.24
# 1                           Human immunodeficiency virus 1              0.25
# 2                           Human immunodeficiency virus 1              0.41
# 3                           Human immunodeficiency virus 1               0.8
# 4                           Human immunodeficiency virus 1              0.99
# ...                                                    ...               ...
# 2909379                     Human immunodeficiency virus 1               170
# 2909380                     Human immunodeficiency virus 1                38
# 2909381                     Human immunodeficiency virus 1               4.0
# 2909382                     Human immunodeficiency virus 1               8.0
# 2909383                     Human immunodeficiency virus 1          0.050000
#
#         IC50 (nM) Kd (nM) EC50 (nM) kon (M-1-s-1) koff (s-1)   pH  ...  \
# 0             NaN     NaN       NaN           NaN        NaN  5.5  ...
# 1             NaN     NaN       NaN           NaN        NaN  5.5  ...
# 2             NaN     NaN       NaN           NaN        NaN  5.5  ...
# 3             NaN     NaN       NaN           NaN        NaN  5.5  ...
# 4             NaN     NaN       NaN           NaN        NaN  5.5  ...
# ...           ...     ...       ...           ...        ...  ...  ...
# 2909379       NaN     NaN       NaN           NaN        NaN  NaN  ...
# 2909380       NaN     NaN       NaN           NaN        NaN  NaN  ...
# 2909381       NaN     NaN       NaN           NaN        NaN  NaN  ...
# 2909382       NaN     NaN       NaN           NaN        NaN  NaN  ...
# 2909383       NaN     NaN       NaN           NaN        NaN  NaN  ...
#
#         BindingDB Target Chain Sequence.3  BindingDB Target Chain Sequence.4  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 2909379                               NaN                                NaN
# 2909380                               NaN                                NaN
# 2909381                               NaN                                NaN
# 2909382                               NaN                                NaN
# 2909383                               NaN                                NaN
#
#         BindingDB Target Chain Sequence.5 BindingDB Target Chain Sequence.6  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 2909379                               NaN                               NaN
# 2909380                               NaN                               NaN
# 2909381                               NaN                               NaN
# 2909382                               NaN                               NaN
# 2909383                               NaN                               NaN
#
#         BindingDB Target Chain Sequence.7 BindingDB Target Chain Sequence.8  \
# 0                                     NaN                               NaN
# 1                                     NaN                               NaN
# 2                                     NaN                               NaN
# 3                                     NaN                               NaN
# 4                                     NaN                               NaN
# ...                                   ...                               ...
# 2909379                               NaN                               NaN
# 2909380                               NaN                               NaN
# 2909381                               NaN                               NaN
# 2909382                               NaN                               NaN
# 2909383                               NaN                               NaN
#
#         BindingDB Target Chain Sequence.9 BindingDB Target Chain Sequence.10  \
# 0                                     NaN                                NaN
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                                NaN
# ...                                   ...                                ...
# 2909379                               NaN                                NaN
# 2909380                               NaN                                NaN
# 2909381                               NaN                                NaN
# 2909382                               NaN                                NaN
# 2909383                               NaN                                NaN
#
#         BindingDB Target Chain Sequence.11 BindingDB Target Chain Sequence.12
# 0                                      NaN                                NaN
# 1                                      NaN                                NaN
# 2                                      NaN                                NaN
# 3                                      NaN                                NaN
# 4                                      NaN                                NaN
# ...                                    ...                                ...
# 2909379                                NaN                                NaN
# 2909380                                NaN                                NaN
# 2909381                                NaN                                NaN
# 2909382                                NaN                                NaN
# 2909383                                NaN                                NaN
#
# [4350 rows x 25 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

target_counts = hiv_data.groupby('Target Name').size().reset_index(name='Compound Count')

# Step 5: Sort targets by the number of compounds
target_counts = target_counts.sort_values(by='Compound Count', ascending=False)
print('Number of targets of the comounds in HIV1: ', target_counts.size)

# Step 6: Plot the distribution of targets
plt.figure(figsize=(12, 6))
sns.barplot(x='Compound Count', y='Target Name', data=target_counts.head(20), palette='viridis')
plt.title('Top 20 Targets by Number of Compounds')
plt.xlabel('Number of Compounds')
plt.ylabel('Target Name')
plt.show()
# Out:
# Number of targets of the comounds in HIV1:  126

# %%
# Import necessary libraries
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.cluster import KMeans
import numpy as np
from rdkit.Chem.rdFingerprintGenerator import GetMorganGenerator

# Step 1: Generate Morgan Fingerprints
def generate_fingerprints(smiles_list, radius=2, n_bits=1024):
    """Generates Morgan fingerprints for a list of SMILES strings using MorganGenerator."""
    generator = GetMorganGenerator(radius=radius, fpSize=n_bits)  
    fingerprints = []
    
    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol:
            fp = generator.GetFingerprint(mol)
            arr = np.zeros((1,), dtype=int)
            AllChem.DataStructs.ConvertToNumpyArray(fp, arr)
            fingerprints.append(arr)
        else:
            fingerprints.append(None)
    
    return np.array([fp for fp in fingerprints if fp is not None])  # Remove None entries

# Load your cleaned dataset
# Assuming the DataFrame 'hiv_data' with a column 'Ligand SMILES' is already prepared
smiles_list = hiv_data['Ligand SMILES'].tolist()

# Generate fingerprints
fingerprint_matrix = generate_fingerprints(smiles_list)

#Standardize the fingerprints
scaler = StandardScaler()
fingerprint_matrix_scaled = scaler.fit_transform(fingerprint_matrix)

# %%
from sklearn.decomposition import PCA
import seaborn as sns
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt


# Perform PCA on the fingerprint matrix
pca = PCA(n_components=2)
pca_result = pca.fit_transform(fingerprint_matrix_scaled)


# Add PCA results to a DataFrame for easier plotting¨
kmeans = KMeans(n_clusters=6, random_state=42)
kmeans.fit(pca_result)
pca_df = pd.DataFrame(pca_result, columns=['PCA1', 'PCA2'])
pca_df['Cluster'] = kmeans.labels_  # Assuming 'kmeans' is the model fitted with an optimal k

# Visualize the PCA result
plt.figure(figsize=(10, 8))
sns.scatterplot(x='PCA1', y='PCA2', hue='Cluster', data=pca_df, palette='viridis')
plt.title('PCA of Morgan Fingerprints Clusters')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
# Step 2: Perform Clustering with KMeans
# Adjust the number of clusters (n_clusters) as needed for your analysis
kmeans = KMeans(n_clusters=6, random_state=42)
kmeans.fit(fingerprint_matrix_scaled)

# Add cluster labels to the DataFrame
hiv_data['Cluster'] = kmeans.labels_

# Display cluster counts
print(hiv_data['Cluster'].value_counts())

# Visualize the distribution of clusters (optional)
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Cluster', data=hiv_data, palette='viridis')
plt.title('Distribution of Clusters')
plt.xlabel('Cluster')
plt.ylabel('Number of Ligands')
plt.show()
# Out:
# 4    1700
# 1    1662
# 5     506
# 3     186
# 0     180
# 2     116
# Name: Cluster, dtype: int64

# %%
cluster_dataframes={}
for cluster in range(6):
    cluster_dataframes[f'Cluster_{cluster}'] = hiv_data[hiv_data['Cluster'] == cluster]
    print(cluster_dataframes[f'Cluster_{cluster}'].groupby('Target Name').size().reset_index(name='Compound Count'))
# Out:
#                                           Target Name  Compound Count
# 0        Dimer of Gag-Pol polyprotein [489-587,I539V]               5
# 1   Dimer of Gag-Pol polyprotein [489-587,L499I,L5...               5
# 2   Dimer of Gag-Pol polyprotein [489-587,M535I,L5...               5
# 3              Dimer of Gag-Pol polyprotein [489-587]              15
# 4   Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               1
# 5   Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               1
# 6   Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               1
# 7   Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               1
# 8   Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               1
# 9   Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...             102
# 10                      Gag-Pol polyprotein [489-587]              43
#                                           Target Name  Compound Count
# 0   Dimer of Gag-Pol polyprotein [482-580,I502K,I5...               6
# 1   Dimer of Gag-Pol polyprotein [482-580,I502K,I5...               6
# 2        Dimer of Gag-Pol polyprotein [489-587,I536L]               1
# 3        Dimer of Gag-Pol polyprotein [489-587,I539L]               1
# 4        Dimer of Gag-Pol polyprotein [489-587,I573V]               1
# 5   Dimer of Gag-Pol polyprotein [489-587,K509R,V5...               4
# 6   Dimer of Gag-Pol polyprotein [489-587,K509R,V5...               4
# 7   Dimer of Gag-Pol polyprotein [489-587,K509R,V5...               4
# 8   Dimer of Gag-Pol polyprotein [489-587,K509R,V5...               4
# 9   Dimer of Gag-Pol polyprotein [489-587,K509R,V5...               4
# 10  Dimer of Gag-Pol polyprotein [489-587,K509R,V5...               4
# 11  Dimer of Gag-Pol polyprotein [489-587,K509R,V5...               4
# 12       Dimer of Gag-Pol polyprotein [489-587,L512I]               1
# 13       Dimer of Gag-Pol polyprotein [489-587,L512V]               1
# 14       Dimer of Gag-Pol polyprotein [489-587,L565M]               1
# 15  Dimer of Gag-Pol polyprotein [489-587,Q496K,I5...               4
# 16  Dimer of Gag-Pol polyprotein [489-587,Q496K,L4...               4
# 17  Dimer of Gag-Pol polyprotein [489-587,Q496K,L4...               4
# 18       Dimer of Gag-Pol polyprotein [489-587,Q496K]               4
# 19       Dimer of Gag-Pol polyprotein [489-587,V521I]               1
# 20       Dimer of Gag-Pol polyprotein [489-587,V571A]               3
# 21       Dimer of Gag-Pol polyprotein [489-587,V571I]               1
# 22             Dimer of Gag-Pol polyprotein [489-587]             254
# 23  Dimer of Gag-Pol polyprotein [490-588,L523I,E5...               6
# 24  Dimer of Gag-Pol polyprotein [490-588,L523I,E5...               6
# 25       Dimer of Gag-Pol polyprotein [491-589,Q496K]              15
# 26  Dimer of Gag-Pol polyprotein [491-589,Q498K,D5...              10
# 27  Dimer of Gag-Pol polyprotein [491-589,Q498K,L5...              10
# 28  Dimer of Gag-Pol polyprotein [491-589,Q498K,L5...              10
# 29  Dimer of Gag-Pol polyprotein [501-599,A572V,V5...               1
# 30       Dimer of Gag-Pol polyprotein [501-599,A572V]               5
# 31  Dimer of Gag-Pol polyprotein [501-599,D531N,A5...               5
# 32  Dimer of Gag-Pol polyprotein [501-599,D531N,M5...               5
# 33  Dimer of Gag-Pol polyprotein [501-599,D531N,M5...               5
# 34  Dimer of Gag-Pol polyprotein [501-599,M537I,A5...               5
# 35       Dimer of Gag-Pol polyprotein [501-599,M537I]               5
# 36  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               6
# 37  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               3
# 38  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               4
# 39  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               1
# 40  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               3
# 41  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               1
# 42  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...               1
# 43  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...              59
# 44       Dimer of Gag-Pol polyprotein [501-599,V583F]               6
# 45             Dimer of Gag-Pol polyprotein [501-599]              30
# 46                      Gag-Pol polyprotein [489-587]             957
# 47  Gag-Pol polyprotein [588-1027,K691N]/[588-1147...               1
# 48  Gag-Pol polyprotein [588-1027,V694A]/[588-1147...               1
# 49  Gag-Pol polyprotein [588-1027,V767D]/[588-1147...               1
# 50  Gag-Pol polyprotein [588-1027,Y769I]/[588-1147...               1
# 51  Gag-Pol polyprotein [588-1027,Y776L]/[588-1147...               1
# 52                     Gag-Pol polyprotein [588-1027]               1
# 53  Gag-Pol polyprotein [588-1127,L687I]/[588-1147...               1
# 54                              Reverse transcriptase              56
# 55                      Reverse transcriptase protein              64
# 56                       Reverse transcriptase/RNaseH              55
#                               Target Name  Compound Count
# 0  Dimer of Gag-Pol polyprotein [489-587]              68
# 1           Gag-Pol polyprotein [489-587]              48
#                                           Target Name  Compound Count
# 0                       Gag-Pol polyprotein [489-587]               2
# 1   Gag-Pol polyprotein [588-1027,K691N]/[588-1147...               3
# 2   Gag-Pol polyprotein [588-1027,V694A]/[588-1147...               1
# 3   Gag-Pol polyprotein [588-1027,V767D]/[588-1147...               3
# 4   Gag-Pol polyprotein [588-1027,Y769I]/[588-1147...               3
# 5   Gag-Pol polyprotein [588-1027,Y776L]/[588-1147...               1
# 6                      Gag-Pol polyprotein [588-1027]               3
# 7   Gag-Pol polyprotein [588-1127,L687I]/[588-1147...               2
# 8                               Reverse transcriptase              18
# 9                       Reverse transcriptase protein              18
# 10                       Reverse transcriptase/RNaseH             132
#                                           Target Name  Compound Count
# 0              Dimer of Gag-Pol polyprotein [489-587]             396
# 1              Dimer of Gag-Pol polyprotein [501-599]             205
# 2                         Envelope glycoprotein gp160              34
# 3                       Gag-Pol polyprotein [489-587]             792
# 4   Gag-Pol polyprotein [588-1027,K691N]/[588-1147...               1
# 5   Gag-Pol polyprotein [588-1027,V694A]/[588-1147...               1
# 6   Gag-Pol polyprotein [588-1027,V767D]/[588-1147...               1
# 7   Gag-Pol polyprotein [588-1027,Y769I]/[588-1147...               1
# 8   Gag-Pol polyprotein [588-1027,Y776L]/[588-1147...               1
# 9                      Gag-Pol polyprotein [588-1027]               1
# 10  Gag-Pol polyprotein [588-1127,L687I]/[588-1147...               1
# 11                                          Integrase               3
# 12                              Reverse transcriptase             183
# 13                      Reverse transcriptase protein              57
# 14                       Reverse transcriptase/RNaseH              23
#                                           Target Name  Compound Count
# 0   Dimer of Gag-Pol polyprotein [482-580,I502K,I5...               1
# 1   Dimer of Gag-Pol polyprotein [482-580,I502K,I5...               1
# 2        Dimer of Gag-Pol polyprotein [489-587,I539V]               1
# 3   Dimer of Gag-Pol polyprotein [489-587,L499I,L5...               1
# 4   Dimer of Gag-Pol polyprotein [489-587,M535I,L5...               1
# 5              Dimer of Gag-Pol polyprotein [489-587]              18
# 6   Dimer of Gag-Pol polyprotein [490-588,L523I,E5...               1
# 7   Dimer of Gag-Pol polyprotein [490-588,L523I,E5...               1
# 8        Dimer of Gag-Pol polyprotein [491-589,Q496K]              47
# 9   Dimer of Gag-Pol polyprotein [491-589,Q498K,D5...               9
# 10  Dimer of Gag-Pol polyprotein [491-589,Q498K,L5...               9
# 11  Dimer of Gag-Pol polyprotein [491-589,Q498K,L5...               9
# 12  Dimer of Gag-Pol polyprotein [491-589,Q7K,L33I...              10
# 13  Dimer of Gag-Pol polyprotein [501-599,Q508K,L5...              70
# 14       Dimer of Gag-Pol polyprotein [501-599,V583F]               1
# 15             Dimer of Gag-Pol polyprotein [501-599]             147
# 16                      Gag-Pol polyprotein [489-587]             179

# %%
index_cluster0 = cluster_dataframes['Cluster_0'].index
index_cluster1 = cluster_dataframes['Cluster_1'].index
index_cluster2 = cluster_dataframes['Cluster_2'].index
index_cluster3 = cluster_dataframes['Cluster_3'].index
index_cluster4 = cluster_dataframes['Cluster_4'].index
index_cluster5 = cluster_dataframes['Cluster_5'].index

# %%
random_index_0 = np.random.choice(index_cluster0, size=5, replace=False)
random_index_1 = np.random.choice(index_cluster1, size=5, replace=False)
random_index_2 = np.random.choice(index_cluster2, size=5, replace=False)
random_index_3 = np.random.choice(index_cluster3, size=5, replace=False)
random_index_4 = np.random.choice(index_cluster4, size=5, replace=False)
random_index_5 = np.random.choice(index_cluster5, size=5, replace=False)

# %%
from rdkit.Chem import Draw
from rdkit import Chem

# Plot random molecules from each cluster
for cluster_index, random_indices in zip(range(6), [random_index_0, random_index_1, random_index_2, random_index_3, random_index_4, random_index_5]):
    cluster_name = f'Cluster_{cluster_index}'
    fig, ax = plt.subplots(1, 5, figsize=(15, 15), sharey=True, sharex=True)
    ax = ax.ravel()  # Flatten the 2D array of axes for easier iteration

    # Loop through the random indices for this cluster
    for idx, random_idx in enumerate(random_indices):
        # Retrieve the SMILES string for the ligand
        smiles = cluster_dataframes[cluster_name].loc[random_idx, 'Ligand SMILES']
        mol = Chem.MolFromSmiles(smiles)

        # Draw the molecule in the corresponding subplot
        img = Draw.MolToImage(mol)
        ax[idx].imshow(img)
        ax[idx].axis('off')  # Hide the axes
        ax[idx].set_title(f"Molecule {random_idx} from {cluster_name}")

    # Adjust the layout and display the plot
    plt.tight_layout()
    plt.show()
